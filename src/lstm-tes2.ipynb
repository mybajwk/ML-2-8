# %%
import os
import random
import numpy as np
import pandas as pd
import tensorflow as tf
import torch as tc
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import f1_score
import time
import matplotlib.pyplot as plt
import pandas as pd
import time
import matplotlib.pyplot as plt
import pandas as pd


from models.lstm.keras_model import build_lstm_model
from models.lstm.scratch_model import ScratchLSTMClassifier
from tensorflow.keras.layers import TextVectorization

# Set seed
SEED = 42
os.environ['PYTHONHASHSEED'] = str(SEED)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
os.environ['TF_CUDNN_DETERMINISTIC'] = '1'
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)  
tc.manual_seed(SEED)
tc.backends.cudnn.deterministic = True
tc.backends.cudnn.benchmark = False
tc.use_deterministic_algorithms(True)
tf.config.experimental.enable_op_determinism()


train = pd.read_csv('./../data/nusaX-sentiment/train.csv')
valid = pd.read_csv('./../data/nusaX-sentiment/valid.csv')
test  = pd.read_csv('./../data/nusaX-sentiment/test.csv')

le = LabelEncoder()
y_train = le.fit_transform(train['label'])
y_val   = le.transform(valid['label'])
y_test  = le.transform(test['label'])
num_classes = len(le.classes_)

texts_train = train['text'].astype(str).tolist()
texts_val   = valid['text'].astype(str).tolist()
texts_test  = test['text'].astype(str).tolist()

exp2 = []
trainloss_dict = {}
valloss_dict = {}
durations = []

max_tokens = 10000
max_len    = 100
embed_dim  = 128

vectorizer = TextVectorization(max_tokens=max_tokens, output_sequence_length=max_len)
vectorizer.adapt(texts_train)
def make_dataset(texts, labels, batch=32, shuffle=True):
    x = vectorizer(tf.constant(texts))
    ds = tf.data.Dataset.from_tensor_slices((x, labels))
    if shuffle: ds = ds.shuffle(1024)
    return ds.batch(batch).prefetch(1)

print("Sample vocab:", vectorizer.get_vocabulary()[:10])
print("Max index:", len(vectorizer.get_vocabulary()))

ds_train = make_dataset(texts_train, y_train)
ds_val   = make_dataset(texts_val,   y_val,   shuffle=False)
ds_test  = make_dataset(texts_test,  y_test,  shuffle=False)

def train_and_eval(params, name):
    print(f"\n=== Running {name}: {params}")
    model = build_lstm_model(**params, max_len=max_len, max_tokens=max_tokens, embed_dim=embed_dim, num_classes=num_classes)
    hist = model.fit(ds_train, validation_data=ds_val, epochs=10, 
        shuffle=False)
    y_pred = np.argmax(model.predict(ds_test), axis=-1)
    f1 = f1_score(y_test, y_pred, average='macro')
    print(f"{name} macro-F1: {f1:.4f}")
    return model, hist, f1

for u in [64, 128, 256]:
    print(f"\n===== [LSTM] Jumlah Unit = {u} =====")
    config = {
        'n_layers': 1,
        'units': [u],
        'bidirectional': True
    }
    start = time.time()
    model, hist, f1_keras = train_and_eval(config, f'units={u}')
    end = time.time()

    label = f"{u} Units"
    trainloss_dict[label] = hist.history['loss']
    valloss_dict[label] = hist.history['val_loss']
    durations.append((label, round(end - start, 2)))
    exp2.append((label, hist))

    # === Save Keras Model Weights ===
    model.save_weights(f'model_lstm_{u}units.weights.h5')
    emb_w = model.layers[1].get_weights()[0]
    d_w, d_b = model.layers[-1].get_weights()
    lstm_layers = [ly for ly in model.layers if isinstance(ly, (tf.keras.layers.LSTM, tf.keras.layers.Bidirectional))]

    def unpack_lstm(layer):
        if isinstance(layer, tf.keras.layers.Bidirectional):
            return_seq = layer.forward_layer.return_sequences
            Wf, Uf, bf = layer.forward_layer.get_weights()
            Wb, Ub, bb = layer.backward_layer.get_weights()
            return ('bidir', return_seq, (Wf, Uf, bf), (Wb, Ub, bb))
        else:
            return_seq = layer.return_sequences
            W, U, b = layer.get_weights()
            return ('unidir', return_seq, (W, U, b))

    scratch_specs = [unpack_lstm(ly) for ly in lstm_layers]
    scratch_model = ScratchLSTMClassifier(emb_w, scratch_specs, d_w, d_b)

    # === Prediksi dan Evaluasi Scratch ===
    x_int = vectorizer(tf.constant(texts_test)).numpy()
    pred_keras = model.predict(ds_test)
    pred_scratch = scratch_model.forward(x_int)
    y_pred_keras = np.argmax(pred_keras, axis=1)
    y_pred_scratch = np.argmax(pred_scratch, axis=1)

    f1_scratch = f1_score(y_test, y_pred_scratch, average='macro')
    print(f"[{u} Units] max|keras - scratch| = {np.max(np.abs(pred_keras - pred_scratch))}")
    print(f"[{u} Units] macro-F1 (Scratch): {f1_scratch:.4f}")

    # === Save Scratch Model ===
    npy_path = f"model_lstm_scratch_{u}units.npy"
    scratch_model.save_npy(npy_path)

    # === Load dan Evaluasi ulang Scratch ===
    scratch_loaded = ScratchLSTMClassifier()
    scratch_loaded.load_npy(npy_path)
    pred_loaded = scratch_loaded.forward(x_int)
    y_loaded = np.argmax(pred_loaded, axis=1)
    f1_loaded = f1_score(y_test, y_loaded, average='macro')
    print(f"[{u} Units] max|scratch - loaded| = {np.max(np.abs(pred_scratch - pred_loaded))}")
    print(f"[{u} Units] macro-F1 (Scratch Loaded): {f1_loaded:.4f}")

# === Plot 1: Train Loss Only ===
plt.figure(figsize=(8, 5))
for label, losses in trainloss_dict.items():
    plt.plot(losses, label=f"{label} - Train Loss")
plt.title("Train Loss vs Epoch (Jumlah Unit LSTM)")
plt.xlabel("Epoch")
plt.ylabel("Train Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# === Plot 2: Validation Loss Only ===
plt.figure(figsize=(8, 5))
for label, losses in valloss_dict.items():
    plt.plot(losses, label=f"{label} - Val Loss")
plt.title("Validation Loss vs Epoch (Jumlah Unit LSTM)")
plt.xlabel("Epoch")
plt.ylabel("Validation Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# === Plot 3: Train vs Val Loss Combined ===
plt.figure(figsize=(8, 5))
for label in trainloss_dict:
    plt.plot(trainloss_dict[label], label=f"{label} - Train")
    plt.plot(valloss_dict[label], label=f"{label} - Val")
plt.title("Train vs Validation Loss (Jumlah Unit LSTM)")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# === Print Durasi Training ke Console ===
print("\n=== Durasi Training per Jumlah Unit LSTM ===")
for label, dur in durations:
    print(f"{label}: {dur:.2f} detik")
# Out:
# Sample vocab: ['', '[UNK]', np.str_('yang'), np.str_('di'), np.str_('dan'), np.str_('tidak'), np.str_('saya'), np.str_('dengan'), np.str_('enak'), np.str_('ini')]
# Max index: 2836
#
# ===== [LSTM] Jumlah Unit = 64 =====
#
# === Running units=64: {'n_layers': 1, 'units': [64], 'bidirectional': True}
# Epoch 1/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 1.0875 - val_loss: 1.0285
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.9823 - val_loss: 0.9152
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.8197 - val_loss: 0.8858
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.6306 - val_loss: 0.7532
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.3981 - val_loss: 0.7496
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.2097 - val_loss: 0.9141
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.1235 - val_loss: 0.6911
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0761 - val_loss: 0.8001
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0350 - val_loss: 0.7925
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - loss: 0.0320 - val_loss: 0.9970
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# units=64 macro-F1: 0.6376
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# [64 Units] max|keras - scratch| = 1.519918441772461e-06
# [64 Units] macro-F1 (Scratch): 0.6376
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: divide by zero encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: overflow encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: invalid value encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: divide by zero encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: overflow encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: invalid value encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: divide by zero encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: overflow encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: invalid value encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# [64 Units] max|scratch - loaded| = 0.0
# [64 Units] macro-F1 (Scratch Loaded): 0.6376
#
# ===== [LSTM] Jumlah Unit = 128 =====
#
# === Running units=128: {'n_layers': 1, 'units': [128], 'bidirectional': True}
# Epoch 1/10
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: divide by zero encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: overflow encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: invalid value encountered in matmul
#   z = x @ self.W + self.b
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 1.0766 - val_loss: 0.9995
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 44ms/step - loss: 0.9182 - val_loss: 0.9125
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.7505 - val_loss: 0.8450
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.5376 - val_loss: 0.7883
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.3461 - val_loss: 0.8925
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.6336 - val_loss: 0.8632
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.2419 - val_loss: 0.9928
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - loss: 0.2699 - val_loss: 0.8606
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - loss: 0.1976 - val_loss: 0.9317
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - loss: 0.1166 - val_loss: 0.9213
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step
# units=128 macro-F1: 0.6856
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step
# [128 Units] max|keras - scratch| = 1.1920928955078125e-06
# [128 Units] macro-F1 (Scratch): 0.6856
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: divide by zero encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: overflow encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: invalid value encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: divide by zero encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: overflow encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: invalid value encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: divide by zero encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: overflow encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: invalid value encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# [128 Units] max|scratch - loaded| = 0.0
# [128 Units] macro-F1 (Scratch Loaded): 0.6856
#
# ===== [LSTM] Jumlah Unit = 256 =====
#
# === Running units=256: {'n_layers': 1, 'units': [256], 'bidirectional': True}
# Epoch 1/10
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: divide by zero encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: overflow encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: invalid value encountered in matmul
#   z = x @ self.W + self.b
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 1.0872 - val_loss: 1.0515
# Epoch 2/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.9923 - val_loss: 0.9372
# Epoch 3/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 94ms/step - loss: 0.7664 - val_loss: 0.8349
# Epoch 4/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 110ms/step - loss: 0.5181 - val_loss: 0.7744
# Epoch 5/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 80ms/step - loss: 0.3024 - val_loss: 0.7853
# Epoch 6/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.1472 - val_loss: 0.9215
# Epoch 7/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 2s 96ms/step - loss: 0.0845 - val_loss: 0.8599
# Epoch 8/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - loss: 0.0353 - val_loss: 0.9377
# Epoch 9/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 76ms/step - loss: 0.0193 - val_loss: 0.9981
# Epoch 10/10
# 16/16 ━━━━━━━━━━━━━━━━━━━━ 1s 75ms/step - loss: 0.0087 - val_loss: 0.9918
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# units=256 macro-F1: 0.7419
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: divide by zero encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: overflow encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: invalid value encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: divide by zero encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: overflow encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: invalid value encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: divide by zero encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: overflow encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/lstm_layer.py:18: RuntimeWarning: invalid value encountered in matmul
#   z = xt @ self.W + H @ self.U + self.b
# [256 Units] max|keras - scratch| = 3.3974647521972656e-06
# [256 Units] macro-F1 (Scratch): 0.7419
# [256 Units] max|scratch - loaded| = 0.0
# [256 Units] macro-F1 (Scratch Loaded): 0.7419
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: divide by zero encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: overflow encountered in matmul
#   z = x @ self.W + self.b
# /Users/enrique/Projects/Coding/ML-2-8/src/models/lstm/dense_layer.py:10: RuntimeWarning: invalid value encountered in matmul
#   z = x @ self.W + self.b
# === Durasi Training per Jumlah Unit LSTM ===
# 64 Units: 4.40 detik
# 128 Units: 6.98 detik
# 256 Units: 14.87 detik
